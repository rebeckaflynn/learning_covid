# %%
pwd
# Out:
# '/Users/rebeckaflynn'

# %%
ls
# Out:
# Applications/                 Movies/
# Covid patients dataset.ipynb  Music/
# Desktop/                      Pictures/
# Documents/                    Public/
# Downloads/                    practical-python/
# Library/

# %%
import pandas as pd 
import numpy as np



patients = pd.read_csv('/Users/rebeckaflynn/Downloads/covid/covid.csv')

# %%
patients.head()
# Out:
#        id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0  16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1  1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2  167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3  0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4  0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# 0          2   27         97  ...        2             2              2
# 1          2   24         97  ...        2             2              2
# 2          2   54          2  ...        2             2              2
# 3          1   30         97  ...        2             2              2
# 4          2   60          2  ...        2             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients.columns
# Out:
# Index(['id', 'sex', 'patient_type', 'entry_date', 'date_symptoms', 'date_died',
#        'intubed', 'pneumonia', 'age', 'pregnancy', 'diabetes', 'copd',
#        'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
#        'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
#        'covid_res', 'icu'],
#       dtype='object')

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566602 entries, 0 to 566601
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   566602 non-null  object
#  1   sex                  566602 non-null  int64
#  2   patient_type         566602 non-null  int64
#  3   entry_date           566602 non-null  object
#  4   date_symptoms        566602 non-null  object
#  5   date_died            566602 non-null  object
#  6   intubed              566602 non-null  int64
#  7   pneumonia            566602 non-null  int64
#  8   age                  566602 non-null  int64
#  9   pregnancy            566602 non-null  int64
#  10  diabetes             566602 non-null  int64
#  11  copd                 566602 non-null  int64
#  12  asthma               566602 non-null  int64
#  13  inmsupr              566602 non-null  int64
#  14  hypertension         566602 non-null  int64
# ...

# %%
patients['entry_date'] = pd.to_datetime(patients['entry_date'])

# %%
patients['date_symptoms'] = pd.to_datetime(patients['date_symptoms'])

# %%
patients['date_died'] = patients['date_died'].replace(to_replace= '9999-99-99', value='1900-01-01')

# %%
patients['date_died'] = pd.to_datetime(patients['date_died'])

# %%
patients.head()
# Out:
#        id  sex  patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    2             1 2020-04-05    2020-02-05 1900-01-01       97
# 1  1009bf    2             1 2020-03-19    2020-03-17 1900-01-01       97
# 2  167386    1             2 2020-06-04    2020-01-04 1900-01-01        2
# 3  0b5948    2             2 2020-04-17    2020-10-04 1900-01-01        2
# 4  0d01b5    1             2 2020-04-13    2020-04-13 2020-04-22        2
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# 0          2   27         97  ...        2             2              2
# 1          2   24         97  ...        2             2              2
# 2          2   54          2  ...        2             2              2
# 3          1   30         97  ...        2             2              2
# 4          2   60          2  ...        2             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients['days until hospitilization'] = patients['entry_date']- patients['date_symptoms']

# %%
patients.head()
# Out:
#        id  sex  patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    2             1 2020-04-05    2020-02-05 1900-01-01       97
# 1  1009bf    2             1 2020-03-19    2020-03-17 1900-01-01       97
# 2  167386    1             2 2020-06-04    2020-01-04 1900-01-01        2
# 3  0b5948    2             2 2020-04-17    2020-10-04 1900-01-01        2
# 4  0d01b5    1             2 2020-04-13    2020-04-13 2020-04-22        2
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27         97  ...             2              2
# 1          2   24         97  ...             2              2
# 2          2   54          2  ...             2              2
# 3          1   30         97  ...             2              2
# 4          2   60          2  ...             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients['intubed'] = patients['intubed'].apply(lambda x: float('nan') if x == 97 else x)

# %%
patients.head()
# Out:
#        id  sex  patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    2             1 2020-04-05    2020-02-05 1900-01-01      NaN
# 1  1009bf    2             1 2020-03-19    2020-03-17 1900-01-01      NaN
# 2  167386    1             2 2020-06-04    2020-01-04 1900-01-01      2.0
# 3  0b5948    2             2 2020-04-17    2020-10-04 1900-01-01      2.0
# 4  0d01b5    1             2 2020-04-13    2020-04-13 2020-04-22      2.0
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27         97  ...             2              2
# 1          2   24         97  ...             2              2
# 2          2   54          2  ...             2              2
# 3          1   30         97  ...             2              2
# 4          2   60          2  ...             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients['sex'] = patients['sex'].apply(lambda x: str('Female') if x == 1 else str('Male'))

# %%
patients.head()
# Out:
#        id     sex  patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    Male             1 2020-04-05    2020-02-05 1900-01-01      NaN
# 1  1009bf    Male             1 2020-03-19    2020-03-17 1900-01-01      NaN
# 2  167386  Female             2 2020-06-04    2020-01-04 1900-01-01      2.0
# 3  0b5948    Male             2 2020-04-17    2020-10-04 1900-01-01      2.0
# 4  0d01b5  Female             2 2020-04-13    2020-04-13 2020-04-22      2.0
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27         97  ...             2              2
# 1          2   24         97  ...             2              2
# 2          2   54          2  ...             2              2
# 3          1   30         97  ...             2              2
# 4          2   60          2  ...             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients['patient_type'] = patients['patient_type'].apply(lambda x: str('Outpatient') if x == 1 else str('Inpatient'))

# %%
patients['pneumonia'] = patients['pneumonia'].apply(lambda x: float('nan') if x == 97 else x)

# %%
patients['pregnancy'] = patients['pregnancy'].apply(lambda x: float('nan') if x == [97,98,99] else x)

# %%
patients['hypertension'] = patients['hypertension'].apply(lambda x: float('nan') if x == [97, 98, 99] else x)

# %%
patients.head()
# Out:
#        id     sex patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    Male   Outpatient 2020-04-05    2020-02-05 1900-01-01      NaN
# 1  1009bf    Male   Outpatient 2020-03-19    2020-03-17 1900-01-01      NaN
# 2  167386  Female    Inpatient 2020-06-04    2020-01-04 1900-01-01      2.0
# 3  0b5948    Male    Inpatient 2020-04-17    2020-10-04 1900-01-01      2.0
# 4  0d01b5  Female    Inpatient 2020-04-13    2020-04-13 2020-04-22      2.0
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27        NaN  ...             2              2
# 1          2   24        NaN  ...             2              2
# 2          2   54        2.0  ...             2              2
# 3          1   30        NaN  ...             2              2
# 4          2   60        2.0  ...             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients['contact_other_covid'] = patients['contact_other_covid'].apply(lambda x: float('nan') if x == 97 else x)

# %%
patients.head()
# Out:
#        id     sex patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    Male   Outpatient 2020-04-05    2020-02-05 1900-01-01      NaN
# 1  1009bf    Male   Outpatient 2020-03-19    2020-03-17 1900-01-01      NaN
# 2  167386  Female    Inpatient 2020-06-04    2020-01-04 1900-01-01      2.0
# 3  0b5948    Male    Inpatient 2020-04-17    2020-10-04 1900-01-01      2.0
# 4  0d01b5  Female    Inpatient 2020-04-13    2020-04-13 2020-04-22      2.0
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27        NaN  ...             2              2
# 1          2   24        NaN  ...             2              2
# 2          2   54        2.0  ...             2              2
# 3          1   30        NaN  ...             2              2
# 4          2   60        2.0  ...             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients['contact_other_covid'] = patients['contact_other_covid'].apply(lambda x: float('nan') if x == 98 else x)

# %%
patients['contact_other_covid'] = patients['contact_other_covid'].apply(lambda x: float('nan') if x == 99 else x)

# %%
patients.head()
# Out:
#        id     sex patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    Male   Outpatient 2020-04-05    2020-02-05 1900-01-01      NaN
# 1  1009bf    Male   Outpatient 2020-03-19    2020-03-17 1900-01-01      NaN
# 2  167386  Female    Inpatient 2020-06-04    2020-01-04 1900-01-01      2.0
# 3  0b5948    Male    Inpatient 2020-04-17    2020-10-04 1900-01-01      2.0
# 4  0d01b5  Female    Inpatient 2020-04-13    2020-04-13 2020-04-22      2.0
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27        NaN  ...             2              2
# 1          2   24        NaN  ...             2              2
# 2          2   54        2.0  ...             2              2
# 3          1   30        NaN  ...             2              2
# 4          2   60        2.0  ...             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients['contact_other_covid'] = patients['contact_other_covid'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients.head()
# Out:
#        id     sex patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    Male   Outpatient 2020-04-05    2020-02-05 1900-01-01      NaN
# 1  1009bf    Male   Outpatient 2020-03-19    2020-03-17 1900-01-01      NaN
# 2  167386  Female    Inpatient 2020-06-04    2020-01-04 1900-01-01      2.0
# 3  0b5948    Male    Inpatient 2020-04-17    2020-10-04 1900-01-01      2.0
# 4  0d01b5  Female    Inpatient 2020-04-13    2020-04-13 2020-04-22      2.0
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27        NaN  ...             2              2
# 1          2   24        NaN  ...             2              2
# 2          2   54        2.0  ...             2              2
# 3          1   30        NaN  ...             2              2
# 4          2   60        2.0  ...             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients['hypertension'] = patients['hypertension'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients.columns
# Out:
# Index(['id', 'sex', 'patient_type', 'entry_date', 'date_symptoms', 'date_died',
#        'intubed', 'pneumonia', 'age', 'pregnancy', 'diabetes', 'copd',
#        'asthma', 'inmsupr', 'hypertension', 'other_disease', 'cardiovascular',
#        'obesity', 'renal_chronic', 'tobacco', 'contact_other_covid',
#        'covid_res', 'icu', 'days until hospitilization'],
#       dtype='object')

# %%
patients['covid_res'] = patients['covid_res'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['diabetes'] = patients['diabetes'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['copd'] = patients['copd'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['asthma'] = patients['asthma'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['inmsupr'] = patients['inmsupr'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['hypertension'] = patients['hypertension'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['other_disease'] = patients['other_disease'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['cardiovascular'] = patients['cardiovascular'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['obesity'] = patients['obesity'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['renal_chronic'] = patients['renal_chronic'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients['tobacco'] = patients['tobacco'].apply(lambda x: float('nan') if x in (97, 98, 99) else x)

# %%
patients.head()
# Out:
#        id     sex patient_type entry_date date_symptoms  date_died intubed  \
# 0  16169f    Male   Outpatient 2020-04-05    2020-02-05 1900-01-01     NaN
# 1  1009bf    Male   Outpatient 2020-03-19    2020-03-17 1900-01-01     NaN
# 2  167386  Female    Inpatient 2020-06-04    2020-01-04 1900-01-01      No
# 3  0b5948    Male    Inpatient 2020-04-17    2020-10-04 1900-01-01      No
# 4  0d01b5  Female    Inpatient 2020-04-13    2020-04-13 2020-04-22      No
#
#   pneumonia age pregnancy  ... hypertension other_disease cardiovascular  \
# 0        No  27       NaN  ...           No            No             No
# 1        No  24       NaN  ...           No            No             No
# 2        No  54        No  ...           No            No             No
# 3       Yes  30       NaN  ...           No            No             No
# 4        No  60        No  ...          Yes            No            Yes
#
#   obesity renal_chronic tobacco contact_other_covid covid_res  icu  \
# ...

# %%
patients = patients.replace({str('Yes'): 1, str('No'): 2})

# %%
patients.head()
# Out:
#        id     sex patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    Male   Outpatient 2020-04-05    2020-02-05 1900-01-01      NaN
# 1  1009bf    Male   Outpatient 2020-03-19    2020-03-17 1900-01-01      NaN
# 2  167386  Female    Inpatient 2020-06-04    2020-01-04 1900-01-01      2.0
# 3  0b5948    Male    Inpatient 2020-04-17    2020-10-04 1900-01-01      2.0
# 4  0d01b5  Female    Inpatient 2020-04-13    2020-04-13 2020-04-22      2.0
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27        NaN  ...           2.0            2.0
# 1          2   24        NaN  ...           2.0            2.0
# 2          2   54        2.0  ...           2.0            2.0
# 3          1   30        NaN  ...           2.0            2.0
# 4          2   60        2.0  ...           1.0            2.0
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients = patients.replace({str('Male'): 2, str('Female'): 1})

# %%
patients.head()
# Out:
#        id  sex patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    2   Outpatient 2020-04-05    2020-02-05 1900-01-01      NaN
# 1  1009bf    2   Outpatient 2020-03-19    2020-03-17 1900-01-01      NaN
# 2  167386    1    Inpatient 2020-06-04    2020-01-04 1900-01-01      2.0
# 3  0b5948    2    Inpatient 2020-04-17    2020-10-04 1900-01-01      2.0
# 4  0d01b5    1    Inpatient 2020-04-13    2020-04-13 2020-04-22      2.0
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27        NaN  ...           2.0            2.0
# 1          2   24        NaN  ...           2.0            2.0
# 2          2   54        2.0  ...           2.0            2.0
# 3          1   30        NaN  ...           2.0            2.0
# 4          2   60        2.0  ...           1.0            2.0
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
patients = patients.replace({str('Outpatient'): 2, str('Inpatient'): 1})

# %%
patients.head()
# Out:
#        id  sex  patient_type entry_date date_symptoms  date_died  intubed  \
# 0  16169f    2             2 2020-04-05    2020-02-05 1900-01-01      NaN
# 1  1009bf    2             2 2020-03-19    2020-03-17 1900-01-01      NaN
# 2  167386    1             1 2020-06-04    2020-01-04 1900-01-01      2.0
# 3  0b5948    2             1 2020-04-17    2020-10-04 1900-01-01      2.0
# 4  0d01b5    1             1 2020-04-13    2020-04-13 2020-04-22      2.0
#
#    pneumonia  age  pregnancy  ...  hypertension  other_disease  \
# 0          2   27        NaN  ...           2.0            2.0
# 1          2   24        NaN  ...           2.0            2.0
# 2          2   54        2.0  ...           2.0            2.0
# 3          1   30        NaN  ...           2.0            2.0
# 4          2   60        2.0  ...           1.0            2.0
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(patients['patient_type'], patients['sex'])

# %%
plt.hist(patients['age'], bins=6, density=True, histtype='stepfilled')
# Out:
# (array([2.68107066e-03, 2.03838850e-02, 1.91062686e-02, 6.69411686e-03,
#         1.12345174e-03, 1.12071613e-05]),
#  array([  0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [<matplotlib.patches.Polygon at 0x7fa79a345820>])
